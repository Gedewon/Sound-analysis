# %%
# !pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.8.1-py3-none-any.whl (203 kB)
#      |████████████████████████████████| 203 kB 91 kB/s  eta 0:00:01
# Requirement already satisfied: decorator>=3.0.0 in /home/gedi/anaconda3/lib/python3.8/site-packages (from librosa) (4.4.2)
# Requirement already satisfied: packaging>=20.0 in /home/gedi/anaconda3/lib/python3.8/site-packages (from librosa) (20.4)
# Collecting resampy>=0.2.2
#   Downloading resampy-0.2.2.tar.gz (323 kB)
#      |████████████████████████████████| 323 kB 57 kB/s eta 0:00:01
# Collecting soundfile>=0.10.2
#   Downloading SoundFile-0.10.3.post1-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: joblib>=0.14 in /home/gedi/anaconda3/lib/python3.8/site-packages (from librosa) (0.16.0)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /home/gedi/anaconda3/lib/python3.8/site-packages (from librosa) (0.23.1)
# Requirement already satisfied: scipy>=1.0.0 in /home/gedi/anaconda3/lib/python3.8/site-packages (from librosa) (1.5.0)
# Requirement already satisfied: numba>=0.43.0 in /home/gedi/anaconda3/lib/python3.8/site-packages (from librosa) (0.50.1)
# Collecting pooch>=1.0
#   Downloading pooch-1.5.1-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 87 kB/s  eta 0:00:01
# Requirement already satisfied: numpy>=1.15.0 in /home/gedi/anaconda3/lib/python3.8/site-packages (from librosa) (1.18.5)
# Collecting audioread>=2.0.0
#   Downloading audioread-2.1.9.tar.gz (377 kB)
#      |████████████████████████████████| 377 kB 137 kB/s eta 0:00:01
# Requirement already satisfied: six in /home/gedi/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->librosa) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/gedi/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: cffi>=1.0 in /home/gedi/anaconda3/lib/python3.8/site-packages (from soundfile>=0.10.2->librosa) (1.14.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gedi/anaconda3/lib/python3.8/site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (2.1.0)
# Requirement already satisfied: llvmlite<0.34,>=0.33.0.dev0 in /home/gedi/anaconda3/lib/python3.8/site-packages (from numba>=0.43.0->librosa) (0.33.0+1.g022ab0f)
# Requirement already satisfied: setuptools in /home/gedi/anaconda3/lib/python3.8/site-packages (from numba>=0.43.0->librosa) (49.2.0.post20200714)
# Requirement already satisfied: requests in /home/gedi/anaconda3/lib/python3.8/site-packages (from pooch>=1.0->librosa) (2.24.0)
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pycparser in /home/gedi/anaconda3/lib/python3.8/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/gedi/anaconda3/lib/python3.8/site-packages (from requests->pooch>=1.0->librosa) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /home/gedi/anaconda3/lib/python3.8/site-packages (from requests->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gedi/anaconda3/lib/python3.8/site-packages (from requests->pooch>=1.0->librosa) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/gedi/anaconda3/lib/python3.8/site-packages (from requests->pooch>=1.0->librosa) (3.0.4)
# Building wheels for collected packages: resampy, audioread
#   Building wheel for resampy (setup.py) ... done
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320720 sha256=651af00badc65a935883d0913b2be1f6e1ccf3df6ea46c402817baa7aa2294bb
#   Stored in directory: /home/gedi/.cache/pip/wheels/6f/d1/5d/f13da53b1dcbc2624ff548456c9ffb526c914f53c12c318bb4
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-2.1.9-py3-none-any.whl size=23142 sha256=299e05e7fcf3c766a9d4b8c9a57fd43a505b8f73b82b0de96971a348821c4f82
#   Stored in directory: /home/gedi/.cache/pip/wheels/49/5a/e4/df590783499a992a88de6c0898991d1167453a3196d0d1eeb7
# Successfully built resampy audioread
# Installing collected packages: resampy, soundfile, appdirs, pooch, audioread, librosa
# Successfully installed appdirs-1.4.4 audioread-2.1.9 librosa-0.8.1 pooch-1.5.1 resampy-0.2.2 soundfile-0.10.3.post1

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
import IPython.display as ipd 
import librosa 
import librosa.display

# %%
filename='./7A864194-4B6B-4850-ABBF-0C2A8170107B-1436846915-1.1-f-26-bu.wav'

# %%
 
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data
# Out:
# array([ 0.00050384,  0.00048624,  0.00032702, ..., -0.00137826,
#        -0.00013251,  0.00027053], dtype=float32)

# %%
import pandas as pd

# %%
sample_rate
# Out:
# 22050

# %%
data.full()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-0d90a727f317> in <module>
# ----> 1 data.full()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'full'
